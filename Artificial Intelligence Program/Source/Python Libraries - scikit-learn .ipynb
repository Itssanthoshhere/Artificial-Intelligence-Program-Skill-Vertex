# %%
import pandas as pd
from sklearn.model_selection import train_test_split

# %% [markdown]
# ##### Load the data

# %%
import pandas as pd
data = pd.read_csv("salary_data.csv")
data
# Out:
#       Age  Gender Education Level                      Job Title  \
# 0    32.0    Male      Bachelor's              Software Engineer
# 1    28.0  Female        Master's                   Data Analyst
# 2    45.0    Male             PhD                 Senior Manager
# 3    36.0  Female      Bachelor's                Sales Associate
# 4    52.0    Male        Master's                       Director
# ..    ...     ...             ...                            ...
# 370  35.0  Female      Bachelor's       Senior Marketing Analyst
# 371  43.0    Male        Master's         Director of Operations
# 372  29.0  Female      Bachelor's         Junior Project Manager
# 373  34.0    Male      Bachelor's  Senior Operations Coordinator
# 374  44.0  Female             PhD        Senior Business Analyst
#
#      Years of Experience    Salary
# 0                    5.0   90000.0
# 1                    3.0   65000.0
# 2                   15.0  150000.0
# 3                    7.0   60000.0
# 4                   20.0  200000.0
# ..                   ...       ...
# 370                  8.0   85000.0
# 371                 19.0  170000.0
# 372                  2.0   40000.0
# 373                  7.0   90000.0
# 374                 15.0  150000.0
#
# [375 rows x 6 columns]

# %% [markdown]
# ##### Separate features and target variable

# %%
x = data.iloc[:,2:4].values
x
# Out:
# array([["Bachelor's", 'Software Engineer'],
#        ["Master's", 'Data Analyst'],
#        ['PhD', 'Senior Manager'],
#        ["Bachelor's", 'Sales Associate'],
#        ["Master's", 'Director'],
#        ["Bachelor's", 'Marketing Analyst'],
#        ["Master's", 'Product Manager'],
#        ["Bachelor's", 'Sales Manager'],
#        ["Bachelor's", 'Marketing Coordinator'],
#        ['PhD', 'Senior Scientist'],
#        ["Master's", 'Software Developer'],
#        ["Bachelor's", 'HR Manager'],
#        ["Bachelor's", 'Financial Analyst'],
#        ["Master's", 'Project Manager'],
#        ["Bachelor's", 'Customer Service Rep'],
#        ["Bachelor's", 'Operations Manager'],
#        ["Master's", 'Marketing Manager'],
#        ['PhD', 'Senior Engineer'],
#        ["Bachelor's", 'Data Entry Clerk'],
#        ["Bachelor's", 'Sales Director'],
#        ["Master's", 'Business Analyst'],
#        ["Master's", 'VP of Operations'],
#        ["Bachelor's", 'IT Support'],
#        ["Bachelor's", 'Recruiter'],
#        ["Master's", 'Financial Manager'],
#        ["Bachelor's", 'Social Media Specialist'],
#        ["Master's", 'Software Manager'],
#        ["Bachelor's", 'Junior Developer'],
#        ['PhD', 'Senior Consultant'],
#        ["Master's", 'Product Designer'],
#        ["Bachelor's", 'CEO'],
#        ["Bachelor's", 'Accountant'],
#        ["Master's", 'Data Scientist'],
#        ["Bachelor's", 'Marketing Specialist'],
#        ['PhD', 'Senior Manager'],
#        ["Bachelor's", 'Technical Writer'],
#        ["Bachelor's", 'HR Generalist'],
#        ["Master's", 'Project Engineer'],
#        ["Bachelor's", 'Customer Success Rep'],
#        ["Bachelor's", 'Sales Executive'],
#        ["Master's", 'UX Designer'],
#        ["Master's", 'Operations Director'],
#        ["Bachelor's", 'Network Engineer'],
#        ["Bachelor's", 'Administrative Assistant'],
#        ["Master's", 'Strategy Consultant'],
#        ["Bachelor's", 'Copywriter'],
#        ["Bachelor's", 'Account Manager'],
#        ["Master's", 'Director of Marketing'],
#        ['PhD', 'Senior Scientist'],
#        ["Bachelor's", 'Help Desk Analyst'],
#        ["Bachelor's", 'Customer Service Manager'],
#        ["Master's", 'Business Intelligence Analyst'],
#        ["Bachelor's", 'Event Coordinator'],
#        ["Master's", 'VP of Finance'],
#        ["Bachelor's", 'Graphic Designer'],
#        ["Bachelor's", 'Sales Manager'],
#        ["Master's", 'UX Researcher'],
#        ['PhD', 'Senior Engineer'],
#        ["Bachelor's", 'Social Media Manager'],
#        ["Master's", 'Product Manager'],
#        ["Master's", 'Director of Operations'],
#        ["Bachelor's", 'Marketing Analyst'],
#        ["Bachelor's", 'HR Manager'],
#        ['PhD', 'Senior Data Scientist'],
#        ["Bachelor's", 'Junior Accountant'],
#        ["Master's", 'Digital Marketing Manager'],
#        ["Bachelor's", 'IT Manager'],
#        ["Bachelor's", 'Customer Service Representative'],
#        ["Master's", 'Business Development Manager'],
#        ["Master's", 'Senior Financial Analyst'],
#        ["Bachelor's", 'Web Developer'],
#        ["Bachelor's", 'Recruiter'],
#        ['PhD', 'Research Director'],
#        ["Bachelor's", 'Technical Support Specialist'],
#        ["Master's", 'Creative Director'],
#        ["Bachelor's", 'Project Manager'],
#        ["Bachelor's", 'Operations Manager'],
#        ["Master's", 'Senior Software Engineer'],
#        ["Master's", 'Human Resources Director'],
#        ["Bachelor's", 'Content Marketing Manager'],
#        ["Bachelor's", 'Technical Recruiter'],
#        ["Master's", 'Data Analyst'],
#        ["Bachelor's", 'Sales Representative'],
#        ['PhD', 'Chief Technology Officer'],
#        ["Bachelor's", 'Junior Designer'],
#        ["Master's", 'Financial Advisor'],
#        ["Bachelor's", 'Junior Account Manager'],
#        ["Bachelor's", 'HR Generalist'],
#        ["Master's", 'Senior Project Manager'],
#        ["Bachelor's", 'Marketing Coordinator'],
#        ['PhD', 'Principal Scientist'],
#        ["Bachelor's", 'Sales Associate'],
#        ["Bachelor's", 'Supply Chain Manager'],
#        ["Master's", 'Senior Marketing Manager'],
#        ["Bachelor's", 'Business Analyst'],
#        ["Bachelor's", 'Training Specialist'],
#        ['PhD', 'Research Scientist'],
#        ["Bachelor's", 'Junior Software Developer'],
#        ["Master's", 'Public Relations Manager'],
#        ["Bachelor's", 'Operations Analyst'],
#        ["Bachelor's", 'Event Coordinator'],
#        ["Master's", 'Product Marketing Manager'],
#        ["Master's", 'Senior HR Manager'],
#        ["Bachelor's", 'Junior Web Developer'],
#        ["Master's", 'Senior Project Coordinator'],
#        ['PhD', 'Chief Data Officer'],
#        ["Bachelor's", 'Digital Content Producer'],
#        ["Bachelor's", 'IT Support Specialist'],
#        ["Master's", 'Senior Marketing Analyst'],
#        ["Bachelor's", 'Customer Success Manager'],
#        ["Master's", 'Senior Graphic Designer'],
#        ["Bachelor's", 'Software Project Manager'],
#        ["Bachelor's", 'Supply Chain Analyst'],
#        ["Master's", 'Senior Business Analyst'],
#        ["Bachelor's", 'Junior Marketing Analyst'],
#        ["Master's", 'Senior Financial Analyst'],
#        ["Bachelor's", 'Office Manager'],
#        ['PhD', 'Principal Engineer'],
#        ["Bachelor's", 'Junior HR Generalist'],
#        ["Master's", 'Senior Product Manager'],
#        ["Bachelor's", 'Sales Manager'],
#        ["Master's", 'Director of Marketing'],
#        ["Bachelor's", 'Junior Operations Analyst'],
#        ["Bachelor's", 'Customer Service Manager'],
#        ['PhD', 'Senior Scientist'],
#        ["Bachelor's", 'Junior Accountant'],
#        ["Master's", 'Senior HR Generalist'],
#        ["Bachelor's", 'Sales Operations Manager'],
#        ["Bachelor's", 'Marketing Coordinator'],
#        ["Master's", 'Senior Software Developer'],
#        ["Master's", 'Director of Operations'],
#        ["Bachelor's", 'Junior Web Designer'],
#        ["Master's", 'Senior Training Specialist'],
#        ['PhD', 'Senior Research Scientist'],
#        ["Bachelor's", 'Junior Sales Representative'],
#        ["Bachelor's", 'Administrative Assistant'],
#        ["Master's", 'Senior Project Manager'],
#        ["Bachelor's", 'Junior Marketing Manager'],
#        ["Bachelor's", 'Junior Data Analyst'],
#        ["Master's", 'Senior Product Marketing Manager'],
#        ["Bachelor's", 'Junior Business Analyst'],
#        ["Master's", 'Senior Marketing Manager'],
#        ["Bachelor's", 'Junior Software Developer'],
#        ["Bachelor's", 'Senior Sales Manager'],
#        ["Master's", 'Junior Marketing Specialist'],
#        ["Bachelor's", 'Senior Business Analyst'],
#        ['PhD', 'Senior Data Scientist'],
#        ["Bachelor's", 'Junior Project Manager'],
#        ["Bachelor's", 'Senior Accountant'],
#        ["Master's", 'Director of Sales'],
#        ["Bachelor's", 'Junior Recruiter'],
#        ["Master's", 'Senior Business Development Manager'],
#        ['PhD', 'Senior Product Designer'],
#        ["Bachelor's", 'Junior Customer Support Specialist'],
#        ["Master's", 'Senior Marketing Analyst'],
#        ["Bachelor's", 'Senior IT Support Specialist'],
#        ["Bachelor's", 'Junior Financial Analyst'],
#        ["Master's", 'Senior Operations Manager'],
#        ['PhD', 'Director of Human Resources'],
#        ["Bachelor's", 'Junior Software Engineer'],
#        ["Bachelor's", 'Senior Sales Representative'],
#        ["Master's", 'Director of Product Management'],
#        ["Bachelor's", 'Junior Copywriter'],
#        ["Bachelor's", 'Senior Marketing Coordinator'],
#        ["Master's", 'Senior Human Resources Manager'],
#        ["Bachelor's", 'Junior Business Development Associate'],
#        ["Bachelor's", 'Senior Account Manager'],
#        ['PhD', 'Senior Researcher'],
#        ["Bachelor's", 'Junior HR Coordinator'],
#        ["Master's", 'Senior Software Engineer'],
#        ["Master's", 'Director of Finance'],
#        ["Bachelor's", 'Junior Marketing Coordinator'],
#        [nan, nan],
#        ["Bachelor's", 'Senior Project Manager'],
#        ["Master's", 'Junior Data Scientist'],
#        ["Bachelor's", 'Senior Operations Analyst'],
#        ['PhD', 'Senior Marketing Manager'],
#        ["Bachelor's", 'Junior Accountant'],
#        ["Bachelor's", 'Senior Human Resources Coordinator'],
#        ["Master's", 'Director of Operations'],
#        ["Bachelor's", 'Junior Sales Representative'],
#        ["Master's", 'Senior Business Analyst'],
#        ['PhD', 'Senior UX Designer'],
#        ["Bachelor's", 'Junior Product Manager'],
#        ["Bachelor's", 'Senior Marketing Specialist'],
#        ["Bachelor's", 'Senior IT Project Manager'],
#        ["Master's", 'Senior Financial Analyst'],
#        ["Bachelor's", 'Senior Quality Assurance Analyst'],
#        ['PhD', 'Director of Sales and Marketing'],
#        ["Bachelor's", 'Junior Operations Analyst'],
#        ["Bachelor's", 'Senior Account Executive'],
#        ["Master's", 'Director of Business Development'],
#        ["Bachelor's", 'Junior Social Media Manager'],
#        ["Bachelor's", 'Senior Product Manager'],
#        ["Master's", 'Senior Human Resources Specialist'],
#        ["Bachelor's", 'Junior Business Analyst'],
#        ["Bachelor's", 'Senior Marketing Coordinator'],
#        ['PhD', 'Senior Data Analyst'],
#        ["Bachelor's", 'Junior Account Manager'],
#        ["Master's", 'Senior Software Developer'],
#        ["Master's", 'Director of Human Capital'],
#        ["Bachelor's", 'Junior Advertising Coordinator'],
#        ["Bachelor's", 'Senior Sales Manager'],
#        ["Master's", 'Junior UX Designer'],
#        ["Bachelor's", 'Senior Accountant'],
#        ['PhD', 'Senior Marketing Director'],
#        ["Bachelor's", 'Junior HR Generalist'],
#        ["Bachelor's", 'Senior Operations Manager'],
#        ["Master's", 'Director of Finance'],
#        ["Bachelor's", 'Junior Marketing Coordinator'],
#        ["Master's", 'Senior IT Consultant'],
#        ['PhD', 'Senior Product Designer'],
#        ["Bachelor's", 'Junior Business Development Associate'],
#        ["Bachelor's", 'Senior Marketing Analyst'],
#        ["Bachelor's", 'Senior Software Engineer'],
#        ["Master's", 'Senior Financial Advisor'],
#        ["Bachelor's", 'Senior Project Coordinator'],
#        ['PhD', 'Director of Operations'],
#        ["Bachelor's", 'Junior Business Operations Analyst'],
#        ["Bachelor's", 'Senior Sales Representative'],
#        ["Master's", 'Director of Marketing'],
#        ["Bachelor's", 'Junior Social Media Specialist'],
#        ["Bachelor's", 'Senior Product Development Manager'],
#        ["Master's", 'Senior Human Resources Manager'],
#        ["Bachelor's", 'Junior Financial Analyst'],
#        ["Bachelor's", 'Senior Marketing Manager'],
#        ['PhD', 'Senior Data Scientist'],
#        ["Bachelor's", 'Junior Operations Manager'],
#        ["Master's", 'Senior Software Architect'],
#        ["Master's", 'Director of Human Resources'],
#        ["Bachelor's", 'Junior Marketing Specialist'],
#        ["Bachelor's", 'Senior Project Manager'],
#        ["Master's", 'Junior Research Scientist'],
#        ["Bachelor's", 'Senior Operations Analyst'],
#        ['PhD', 'Senior Marketing Manager'],
#        ["Bachelor's", 'Junior Sales Representative'],
#        ["Bachelor's", 'Senior Financial Analyst'],
#        ["Master's", 'Senior Software Developer'],
#        ["Bachelor's", 'Junior Operations Analyst'],
#        ["Bachelor's", 'Senior Marketing Specialist'],
#        ['PhD', 'Senior HR Manager'],
#        ["Bachelor's", 'Junior Business Analyst'],
#        ["Bachelor's", 'Senior Product Manager'],
#        ['PhD', 'Senior Data Analyst'],
#        ["Bachelor's", 'Junior Marketing Analyst'],
#        ["Bachelor's", 'Senior Operations Manager'],
#        ["Master's", 'Director of Marketing'],
#        ["Bachelor's", 'Junior Financial Analyst'],
#        ["Bachelor's", 'Senior Project Coordinator'],
#        ["Master's", 'Director of Operations'],
#        ["Bachelor's", 'Junior Marketing Coordinator'],
#        ["Master's", 'Senior IT Consultant'],
#        ['PhD', 'Senior Product Designer'],
#        ["Bachelor's", 'Junior Business Development Associate'],
#        ["Bachelor's", 'Senior Marketing Analyst'],
#        ["Bachelor's", 'Senior Software Engineer'],
#        ["Master's", 'Senior Financial Advisor'],
#        ["Bachelor's", 'Senior Project Coordinator'],
#        ['PhD', 'Director of Operations'],
#        ["Bachelor's", 'Junior Business Operations Analyst'],
#        [nan, nan],
#        ["Bachelor's", 'Senior Financial Manager'],
#        ['PhD', 'Senior Data Scientist'],
#        ["Bachelor's", 'Junior Marketing Coordinator'],
#        ["Bachelor's", 'Senior Operations Manager'],
#        ["Bachelor's", 'Junior Sales Representative'],
#        ["Bachelor's", 'Senior Marketing Specialist'],
#        ["Master's", 'Senior HR Specialist'],
#        ["Bachelor's", 'Junior Operations Manager'],
#        ["Bachelor's", 'Senior Marketing Coordinator'],
#        ['PhD', 'Senior Data Engineer'],
#        ["Bachelor's", 'Junior Marketing Manager'],
#        ["Bachelor's", 'Senior Financial Analyst'],
#        ["Master's", 'Director of Marketing'],
#        ["Bachelor's", 'Junior Business Analyst'],
#        ["Bachelor's", 'Senior Project Manager'],
#        ['PhD', 'Senior Data Analyst'],
#        ["Bachelor's", 'Junior Financial Analyst'],
#        ["Bachelor's", 'Senior Product Manager'],
#        ["Master's", 'Director of Operations'],
#        ["Bachelor's", 'Junior Operations Analyst'],
#        ["Bachelor's", 'Senior Project Coordinator'],
#        ["Master's", 'Director of Marketing'],
#        ["Bachelor's", 'Junior Business Development Associate'],
#        ["Bachelor's", 'Senior Financial Manager'],
#        ['PhD', 'Senior Product Designer'],
#        ["Bachelor's", 'Junior Business Analyst'],
#        ["Bachelor's", 'Senior Marketing Analyst'],
#        ["Bachelor's", 'Senior Software Engineer'],
#        ["Bachelor's", 'Junior Product Manager'],
#        ["Bachelor's", 'Senior Business Analyst'],
#        ['PhD', 'Director of Operations'],
#        ["Bachelor's", 'Junior Marketing Specialist'],
#        ["Bachelor's", 'Senior Business Development Manager'],
#        ["Master's", 'Senior HR Manager'],
#        ["Bachelor's", 'Junior Financial Analyst'],
#        ["Bachelor's", 'Senior Marketing Manager'],
#        ['PhD', 'Senior Data Scientist'],
#        ["Bachelor's", 'Junior Operations Coordinator'],
#        ["Bachelor's", 'Senior Marketing Analyst'],
#        ["Master's", 'Director of HR'],
#        ["Bachelor's", 'Junior Project Manager'],
#        ["Bachelor's", 'Senior Operations Coordinator'],
#        ['PhD', 'Senior Data Engineer'],
#        ["Bachelor's", 'Junior Marketing Manager'],
#        ["Bachelor's", 'Senior Business Analyst'],
#        ["Master's", 'Director of Marketing'],
#        ["Bachelor's", 'Junior Operations Analyst'],
#        ["Bachelor's", 'Senior Project Manager'],
#        ["Master's", 'Director of Marketing'],
#        ["Bachelor's", 'Junior Business Development Associate'],
#        ["Bachelor's", 'Senior Financial Manager'],
#        ['PhD', 'Senior Product Designer'],
#        ["Bachelor's", 'Junior Business Analyst'],
#        ["Bachelor's", 'Senior Marketing Analyst'],
#        ["Bachelor's", 'Senior Software Engineer'],
#        ["Master's", 'Senior Financial Advisor'],
#        ["Bachelor's", 'Senior Marketing Specialist'],
#        ["Bachelor's", 'Junior HR Coordinator'],
#        ["Bachelor's", 'Senior Business Development Manager'],
#        ["Master's", 'Senior Marketing Manager'],
#        ["Bachelor's", 'Junior Financial Advisor'],
#        ["Bachelor's", 'Senior Project Manager'],
#        ['PhD', 'Director of Engineering'],
#        ["Bachelor's", 'Junior Marketing Analyst'],
#        ["Bachelor's", 'Senior Operations Manager'],
#        ['PhD', 'Senior Data Scientist'],
#        ["Bachelor's", 'Junior Marketing Coordinator'],
#        ["Bachelor's", 'Senior Business Analyst'],
#        ["Master's", 'Director of Marketing'],
#        ["Bachelor's", 'Junior Business Development Associate'],
#        ["Bachelor's", 'Senior Financial Analyst'],
#        ['PhD', 'Senior UX Designer'],
#        ["Bachelor's", 'Junior Product Manager'],
#        ["Bachelor's", 'Senior Marketing Manager'],
#        ["Master's", 'Director of Operations'],
#        ["Bachelor's", 'Junior Project Manager'],
#        ["Bachelor's", 'Senior Operations Coordinator'],
#        ['PhD', 'Senior Business Analyst'],
#        ["Bachelor's", 'Junior Marketing Specialist'],
#        ["Bachelor's", 'Senior Financial Manager'],
#        ["Master's", 'Director of Marketing'],
#        ["Bachelor's", 'Junior Financial Analyst'],
#        ["Bachelor's", 'Senior Product Manager'],
#        ['PhD', 'Senior Data Engineer'],
#        ["Bachelor's", 'Junior Business Analyst'],
#        ["Bachelor's", 'Senior Marketing Analyst'],
#        ["Master's", 'Director of Engineering'],
#        ["Bachelor's", 'Junior Operations Manager'],
#        ["Bachelor's", 'Senior Business Development Manager'],
#        ['PhD', 'Senior Data Scientist'],
#        ["Bachelor's", 'Junior Marketing Coordinator'],
#        ["Bachelor's", 'Senior Business Analyst'],
#        ["Master's", 'Director of Marketing'],
#        ["Bachelor's", 'Junior Business Development Associate'],
#        ["Bachelor's", 'Senior Financial Analyst'],
#        ['PhD', 'Senior UX Designer'],
#        ["Bachelor's", 'Junior Product Manager'],
#        ["Bachelor's", 'Senior Marketing Manager'],
#        ["Master's", 'Director of Operations'],
#        ["Bachelor's", 'Junior Project Manager'],
#        ["Bachelor's", 'Senior Operations Coordinator'],
#        ['PhD', 'Senior Business Analyst'],
#        ["Bachelor's", 'Junior Marketing Specialist'],
#        ["Bachelor's", 'Senior Financial Manager'],
#        ["Master's", 'Director of Marketing'],
#        ["Bachelor's", 'Junior Financial Analyst'],
#        ["Bachelor's", 'Senior Product Manager'],
#        ['PhD', 'Senior Data Engineer'],
#        ["Bachelor's", 'Junior Business Analyst'],
#        ["Bachelor's", 'Senior Marketing Analyst'],
#        ["Master's", 'Director of Operations'],
#        ["Bachelor's", 'Junior Project Manager'],
#        ["Bachelor's", 'Senior Operations Coordinator'],
#        ['PhD', 'Senior Business Analyst']], dtype=object)

# %%
X = data[['Education Level', 'Job Title']].values
x
# Out:
# array([["Bachelor's", 'Software Engineer'],
#        ["Master's", 'Data Analyst'],
#        ['PhD', 'Senior Manager'],
#        ["Bachelor's", 'Sales Associate'],
#        ["Master's", 'Director'],
#        ["Bachelor's", 'Marketing Analyst'],
#        ["Master's", 'Product Manager'],
#        ["Bachelor's", 'Sales Manager'],
#        ["Bachelor's", 'Marketing Coordinator'],
#        ['PhD', 'Senior Scientist'],
#        ["Master's", 'Software Developer'],
#        ["Bachelor's", 'HR Manager'],
#        ["Bachelor's", 'Financial Analyst'],
#        ["Master's", 'Project Manager'],
#        ["Bachelor's", 'Customer Service Rep'],
#        ["Bachelor's", 'Operations Manager'],
#        ["Master's", 'Marketing Manager'],
#        ['PhD', 'Senior Engineer'],
#        ["Bachelor's", 'Data Entry Clerk'],
#        ["Bachelor's", 'Sales Director'],
#        ["Master's", 'Business Analyst'],
#        ["Master's", 'VP of Operations'],
#        ["Bachelor's", 'IT Support'],
#        ["Bachelor's", 'Recruiter'],
#        ["Master's", 'Financial Manager'],
#        ["Bachelor's", 'Social Media Specialist'],
#        ["Master's", 'Software Manager'],
#        ["Bachelor's", 'Junior Developer'],
#        ['PhD', 'Senior Consultant'],
#        ["Master's", 'Product Designer'],
#        ["Bachelor's", 'CEO'],
#        ["Bachelor's", 'Accountant'],
#        ["Master's", 'Data Scientist'],
#        ["Bachelor's", 'Marketing Specialist'],
#        ['PhD', 'Senior Manager'],
#        ["Bachelor's", 'Technical Writer'],
#        ["Bachelor's", 'HR Generalist'],
#        ["Master's", 'Project Engineer'],
#        ["Bachelor's", 'Customer Success Rep'],
#        ["Bachelor's", 'Sales Executive'],
#        ["Master's", 'UX Designer'],
#        ["Master's", 'Operations Director'],
#        ["Bachelor's", 'Network Engineer'],
#        ["Bachelor's", 'Administrative Assistant'],
#        ["Master's", 'Strategy Consultant'],
#        ["Bachelor's", 'Copywriter'],
#        ["Bachelor's", 'Account Manager'],
#        ["Master's", 'Director of Marketing'],
#        ['PhD', 'Senior Scientist'],
#        ["Bachelor's", 'Help Desk Analyst'],
#        ["Bachelor's", 'Customer Service Manager'],
#        ["Master's", 'Business Intelligence Analyst'],
#        ["Bachelor's", 'Event Coordinator'],
#        ["Master's", 'VP of Finance'],
#        ["Bachelor's", 'Graphic Designer'],
#        ["Bachelor's", 'Sales Manager'],
#        ["Master's", 'UX Researcher'],
#        ['PhD', 'Senior Engineer'],
#        ["Bachelor's", 'Social Media Manager'],
#        ["Master's", 'Product Manager'],
#        ["Master's", 'Director of Operations'],
#        ["Bachelor's", 'Marketing Analyst'],
#        ["Bachelor's", 'HR Manager'],
#        ['PhD', 'Senior Data Scientist'],
#        ["Bachelor's", 'Junior Accountant'],
#        ["Master's", 'Digital Marketing Manager'],
#        ["Bachelor's", 'IT Manager'],
#        ["Bachelor's", 'Customer Service Representative'],
#        ["Master's", 'Business Development Manager'],
#        ["Master's", 'Senior Financial Analyst'],
#        ["Bachelor's", 'Web Developer'],
#        ["Bachelor's", 'Recruiter'],
#        ['PhD', 'Research Director'],
#        ["Bachelor's", 'Technical Support Specialist'],
#        ["Master's", 'Creative Director'],
#        ["Bachelor's", 'Project Manager'],
#        ["Bachelor's", 'Operations Manager'],
#        ["Master's", 'Senior Software Engineer'],
#        ["Master's", 'Human Resources Director'],
#        ["Bachelor's", 'Content Marketing Manager'],
#        ["Bachelor's", 'Technical Recruiter'],
#        ["Master's", 'Data Analyst'],
#        ["Bachelor's", 'Sales Representative'],
#        ['PhD', 'Chief Technology Officer'],
#        ["Bachelor's", 'Junior Designer'],
#        ["Master's", 'Financial Advisor'],
#        ["Bachelor's", 'Junior Account Manager'],
#        ["Bachelor's", 'HR Generalist'],
#        ["Master's", 'Senior Project Manager'],
#        ["Bachelor's", 'Marketing Coordinator'],
#        ['PhD', 'Principal Scientist'],
#        ["Bachelor's", 'Sales Associate'],
#        ["Bachelor's", 'Supply Chain Manager'],
#        ["Master's", 'Senior Marketing Manager'],
#        ["Bachelor's", 'Business Analyst'],
#        ["Bachelor's", 'Training Specialist'],
#        ['PhD', 'Research Scientist'],
#        ["Bachelor's", 'Junior Software Developer'],
#        ["Master's", 'Public Relations Manager'],
#        ["Bachelor's", 'Operations Analyst'],
#        ["Bachelor's", 'Event Coordinator'],
#        ["Master's", 'Product Marketing Manager'],
#        ["Master's", 'Senior HR Manager'],
#        ["Bachelor's", 'Junior Web Developer'],
#        ["Master's", 'Senior Project Coordinator'],
#        ['PhD', 'Chief Data Officer'],
#        ["Bachelor's", 'Digital Content Producer'],
#        ["Bachelor's", 'IT Support Specialist'],
#        ["Master's", 'Senior Marketing Analyst'],
#        ["Bachelor's", 'Customer Success Manager'],
#        ["Master's", 'Senior Graphic Designer'],
#        ["Bachelor's", 'Software Project Manager'],
#        ["Bachelor's", 'Supply Chain Analyst'],
#        ["Master's", 'Senior Business Analyst'],
#        ["Bachelor's", 'Junior Marketing Analyst'],
#        ["Master's", 'Senior Financial Analyst'],
#        ["Bachelor's", 'Office Manager'],
#        ['PhD', 'Principal Engineer'],
#        ["Bachelor's", 'Junior HR Generalist'],
#        ["Master's", 'Senior Product Manager'],
#        ["Bachelor's", 'Sales Manager'],
#        ["Master's", 'Director of Marketing'],
#        ["Bachelor's", 'Junior Operations Analyst'],
#        ["Bachelor's", 'Customer Service Manager'],
#        ['PhD', 'Senior Scientist'],
#        ["Bachelor's", 'Junior Accountant'],
#        ["Master's", 'Senior HR Generalist'],
#        ["Bachelor's", 'Sales Operations Manager'],
#        ["Bachelor's", 'Marketing Coordinator'],
#        ["Master's", 'Senior Software Developer'],
#        ["Master's", 'Director of Operations'],
#        ["Bachelor's", 'Junior Web Designer'],
#        ["Master's", 'Senior Training Specialist'],
#        ['PhD', 'Senior Research Scientist'],
#        ["Bachelor's", 'Junior Sales Representative'],
#        ["Bachelor's", 'Administrative Assistant'],
#        ["Master's", 'Senior Project Manager'],
#        ["Bachelor's", 'Junior Marketing Manager'],
#        ["Bachelor's", 'Junior Data Analyst'],
#        ["Master's", 'Senior Product Marketing Manager'],
#        ["Bachelor's", 'Junior Business Analyst'],
#        ["Master's", 'Senior Marketing Manager'],
#        ["Bachelor's", 'Junior Software Developer'],
#        ["Bachelor's", 'Senior Sales Manager'],
#        ["Master's", 'Junior Marketing Specialist'],
#        ["Bachelor's", 'Senior Business Analyst'],
#        ['PhD', 'Senior Data Scientist'],
#        ["Bachelor's", 'Junior Project Manager'],
#        ["Bachelor's", 'Senior Accountant'],
#        ["Master's", 'Director of Sales'],
#        ["Bachelor's", 'Junior Recruiter'],
#        ["Master's", 'Senior Business Development Manager'],
#        ['PhD', 'Senior Product Designer'],
#        ["Bachelor's", 'Junior Customer Support Specialist'],
#        ["Master's", 'Senior Marketing Analyst'],
#        ["Bachelor's", 'Senior IT Support Specialist'],
#        ["Bachelor's", 'Junior Financial Analyst'],
#        ["Master's", 'Senior Operations Manager'],
#        ['PhD', 'Director of Human Resources'],
#        ["Bachelor's", 'Junior Software Engineer'],
#        ["Bachelor's", 'Senior Sales Representative'],
#        ["Master's", 'Director of Product Management'],
#        ["Bachelor's", 'Junior Copywriter'],
#        ["Bachelor's", 'Senior Marketing Coordinator'],
#        ["Master's", 'Senior Human Resources Manager'],
#        ["Bachelor's", 'Junior Business Development Associate'],
#        ["Bachelor's", 'Senior Account Manager'],
#        ['PhD', 'Senior Researcher'],
#        ["Bachelor's", 'Junior HR Coordinator'],
#        ["Master's", 'Senior Software Engineer'],
#        ["Master's", 'Director of Finance'],
#        ["Bachelor's", 'Junior Marketing Coordinator'],
#        [nan, nan],
#        ["Bachelor's", 'Senior Project Manager'],
#        ["Master's", 'Junior Data Scientist'],
#        ["Bachelor's", 'Senior Operations Analyst'],
#        ['PhD', 'Senior Marketing Manager'],
#        ["Bachelor's", 'Junior Accountant'],
#        ["Bachelor's", 'Senior Human Resources Coordinator'],
#        ["Master's", 'Director of Operations'],
#        ["Bachelor's", 'Junior Sales Representative'],
#        ["Master's", 'Senior Business Analyst'],
#        ['PhD', 'Senior UX Designer'],
#        ["Bachelor's", 'Junior Product Manager'],
#        ["Bachelor's", 'Senior Marketing Specialist'],
#        ["Bachelor's", 'Senior IT Project Manager'],
#        ["Master's", 'Senior Financial Analyst'],
#        ["Bachelor's", 'Senior Quality Assurance Analyst'],
#        ['PhD', 'Director of Sales and Marketing'],
#        ["Bachelor's", 'Junior Operations Analyst'],
#        ["Bachelor's", 'Senior Account Executive'],
#        ["Master's", 'Director of Business Development'],
#        ["Bachelor's", 'Junior Social Media Manager'],
#        ["Bachelor's", 'Senior Product Manager'],
#        ["Master's", 'Senior Human Resources Specialist'],
#        ["Bachelor's", 'Junior Business Analyst'],
#        ["Bachelor's", 'Senior Marketing Coordinator'],
#        ['PhD', 'Senior Data Analyst'],
#        ["Bachelor's", 'Junior Account Manager'],
#        ["Master's", 'Senior Software Developer'],
#        ["Master's", 'Director of Human Capital'],
#        ["Bachelor's", 'Junior Advertising Coordinator'],
#        ["Bachelor's", 'Senior Sales Manager'],
#        ["Master's", 'Junior UX Designer'],
#        ["Bachelor's", 'Senior Accountant'],
#        ['PhD', 'Senior Marketing Director'],
#        ["Bachelor's", 'Junior HR Generalist'],
#        ["Bachelor's", 'Senior Operations Manager'],
#        ["Master's", 'Director of Finance'],
#        ["Bachelor's", 'Junior Marketing Coordinator'],
#        ["Master's", 'Senior IT Consultant'],
#        ['PhD', 'Senior Product Designer'],
#        ["Bachelor's", 'Junior Business Development Associate'],
#        ["Bachelor's", 'Senior Marketing Analyst'],
#        ["Bachelor's", 'Senior Software Engineer'],
#        ["Master's", 'Senior Financial Advisor'],
#        ["Bachelor's", 'Senior Project Coordinator'],
#        ['PhD', 'Director of Operations'],
#        ["Bachelor's", 'Junior Business Operations Analyst'],
#        ["Bachelor's", 'Senior Sales Representative'],
#        ["Master's", 'Director of Marketing'],
#        ["Bachelor's", 'Junior Social Media Specialist'],
#        ["Bachelor's", 'Senior Product Development Manager'],
#        ["Master's", 'Senior Human Resources Manager'],
#        ["Bachelor's", 'Junior Financial Analyst'],
#        ["Bachelor's", 'Senior Marketing Manager'],
#        ['PhD', 'Senior Data Scientist'],
#        ["Bachelor's", 'Junior Operations Manager'],
#        ["Master's", 'Senior Software Architect'],
#        ["Master's", 'Director of Human Resources'],
#        ["Bachelor's", 'Junior Marketing Specialist'],
#        ["Bachelor's", 'Senior Project Manager'],
#        ["Master's", 'Junior Research Scientist'],
#        ["Bachelor's", 'Senior Operations Analyst'],
#        ['PhD', 'Senior Marketing Manager'],
#        ["Bachelor's", 'Junior Sales Representative'],
#        ["Bachelor's", 'Senior Financial Analyst'],
#        ["Master's", 'Senior Software Developer'],
#        ["Bachelor's", 'Junior Operations Analyst'],
#        ["Bachelor's", 'Senior Marketing Specialist'],
#        ['PhD', 'Senior HR Manager'],
#        ["Bachelor's", 'Junior Business Analyst'],
#        ["Bachelor's", 'Senior Product Manager'],
#        ['PhD', 'Senior Data Analyst'],
#        ["Bachelor's", 'Junior Marketing Analyst'],
#        ["Bachelor's", 'Senior Operations Manager'],
#        ["Master's", 'Director of Marketing'],
#        ["Bachelor's", 'Junior Financial Analyst'],
#        ["Bachelor's", 'Senior Project Coordinator'],
#        ["Master's", 'Director of Operations'],
#        ["Bachelor's", 'Junior Marketing Coordinator'],
#        ["Master's", 'Senior IT Consultant'],
#        ['PhD', 'Senior Product Designer'],
#        ["Bachelor's", 'Junior Business Development Associate'],
#        ["Bachelor's", 'Senior Marketing Analyst'],
#        ["Bachelor's", 'Senior Software Engineer'],
#        ["Master's", 'Senior Financial Advisor'],
#        ["Bachelor's", 'Senior Project Coordinator'],
#        ['PhD', 'Director of Operations'],
#        ["Bachelor's", 'Junior Business Operations Analyst'],
#        [nan, nan],
#        ["Bachelor's", 'Senior Financial Manager'],
#        ['PhD', 'Senior Data Scientist'],
#        ["Bachelor's", 'Junior Marketing Coordinator'],
#        ["Bachelor's", 'Senior Operations Manager'],
#        ["Bachelor's", 'Junior Sales Representative'],
#        ["Bachelor's", 'Senior Marketing Specialist'],
#        ["Master's", 'Senior HR Specialist'],
#        ["Bachelor's", 'Junior Operations Manager'],
#        ["Bachelor's", 'Senior Marketing Coordinator'],
#        ['PhD', 'Senior Data Engineer'],
#        ["Bachelor's", 'Junior Marketing Manager'],
#        ["Bachelor's", 'Senior Financial Analyst'],
#        ["Master's", 'Director of Marketing'],
#        ["Bachelor's", 'Junior Business Analyst'],
#        ["Bachelor's", 'Senior Project Manager'],
#        ['PhD', 'Senior Data Analyst'],
#        ["Bachelor's", 'Junior Financial Analyst'],
#        ["Bachelor's", 'Senior Product Manager'],
#        ["Master's", 'Director of Operations'],
#        ["Bachelor's", 'Junior Operations Analyst'],
#        ["Bachelor's", 'Senior Project Coordinator'],
#        ["Master's", 'Director of Marketing'],
#        ["Bachelor's", 'Junior Business Development Associate'],
#        ["Bachelor's", 'Senior Financial Manager'],
#        ['PhD', 'Senior Product Designer'],
#        ["Bachelor's", 'Junior Business Analyst'],
#        ["Bachelor's", 'Senior Marketing Analyst'],
#        ["Bachelor's", 'Senior Software Engineer'],
#        ["Bachelor's", 'Junior Product Manager'],
#        ["Bachelor's", 'Senior Business Analyst'],
#        ['PhD', 'Director of Operations'],
#        ["Bachelor's", 'Junior Marketing Specialist'],
#        ["Bachelor's", 'Senior Business Development Manager'],
#        ["Master's", 'Senior HR Manager'],
#        ["Bachelor's", 'Junior Financial Analyst'],
#        ["Bachelor's", 'Senior Marketing Manager'],
#        ['PhD', 'Senior Data Scientist'],
#        ["Bachelor's", 'Junior Operations Coordinator'],
#        ["Bachelor's", 'Senior Marketing Analyst'],
#        ["Master's", 'Director of HR'],
#        ["Bachelor's", 'Junior Project Manager'],
#        ["Bachelor's", 'Senior Operations Coordinator'],
#        ['PhD', 'Senior Data Engineer'],
#        ["Bachelor's", 'Junior Marketing Manager'],
#        ["Bachelor's", 'Senior Business Analyst'],
#        ["Master's", 'Director of Marketing'],
#        ["Bachelor's", 'Junior Operations Analyst'],
#        ["Bachelor's", 'Senior Project Manager'],
#        ["Master's", 'Director of Marketing'],
#        ["Bachelor's", 'Junior Business Development Associate'],
#        ["Bachelor's", 'Senior Financial Manager'],
#        ['PhD', 'Senior Product Designer'],
#        ["Bachelor's", 'Junior Business Analyst'],
#        ["Bachelor's", 'Senior Marketing Analyst'],
#        ["Bachelor's", 'Senior Software Engineer'],
#        ["Master's", 'Senior Financial Advisor'],
#        ["Bachelor's", 'Senior Marketing Specialist'],
#        ["Bachelor's", 'Junior HR Coordinator'],
#        ["Bachelor's", 'Senior Business Development Manager'],
#        ["Master's", 'Senior Marketing Manager'],
#        ["Bachelor's", 'Junior Financial Advisor'],
#        ["Bachelor's", 'Senior Project Manager'],
#        ['PhD', 'Director of Engineering'],
#        ["Bachelor's", 'Junior Marketing Analyst'],
#        ["Bachelor's", 'Senior Operations Manager'],
#        ['PhD', 'Senior Data Scientist'],
#        ["Bachelor's", 'Junior Marketing Coordinator'],
#        ["Bachelor's", 'Senior Business Analyst'],
#        ["Master's", 'Director of Marketing'],
#        ["Bachelor's", 'Junior Business Development Associate'],
#        ["Bachelor's", 'Senior Financial Analyst'],
#        ['PhD', 'Senior UX Designer'],
#        ["Bachelor's", 'Junior Product Manager'],
#        ["Bachelor's", 'Senior Marketing Manager'],
#        ["Master's", 'Director of Operations'],
#        ["Bachelor's", 'Junior Project Manager'],
#        ["Bachelor's", 'Senior Operations Coordinator'],
#        ['PhD', 'Senior Business Analyst'],
#        ["Bachelor's", 'Junior Marketing Specialist'],
#        ["Bachelor's", 'Senior Financial Manager'],
#        ["Master's", 'Director of Marketing'],
#        ["Bachelor's", 'Junior Financial Analyst'],
#        ["Bachelor's", 'Senior Product Manager'],
#        ['PhD', 'Senior Data Engineer'],
#        ["Bachelor's", 'Junior Business Analyst'],
#        ["Bachelor's", 'Senior Marketing Analyst'],
#        ["Master's", 'Director of Engineering'],
#        ["Bachelor's", 'Junior Operations Manager'],
#        ["Bachelor's", 'Senior Business Development Manager'],
#        ['PhD', 'Senior Data Scientist'],
#        ["Bachelor's", 'Junior Marketing Coordinator'],
#        ["Bachelor's", 'Senior Business Analyst'],
#        ["Master's", 'Director of Marketing'],
#        ["Bachelor's", 'Junior Business Development Associate'],
#        ["Bachelor's", 'Senior Financial Analyst'],
#        ['PhD', 'Senior UX Designer'],
#        ["Bachelor's", 'Junior Product Manager'],
#        ["Bachelor's", 'Senior Marketing Manager'],
#        ["Master's", 'Director of Operations'],
#        ["Bachelor's", 'Junior Project Manager'],
#        ["Bachelor's", 'Senior Operations Coordinator'],
#        ['PhD', 'Senior Business Analyst'],
#        ["Bachelor's", 'Junior Marketing Specialist'],
#        ["Bachelor's", 'Senior Financial Manager'],
#        ["Master's", 'Director of Marketing'],
#        ["Bachelor's", 'Junior Financial Analyst'],
#        ["Bachelor's", 'Senior Product Manager'],
#        ['PhD', 'Senior Data Engineer'],
#        ["Bachelor's", 'Junior Business Analyst'],
#        ["Bachelor's", 'Senior Marketing Analyst'],
#        ["Master's", 'Director of Operations'],
#        ["Bachelor's", 'Junior Project Manager'],
#        ["Bachelor's", 'Senior Operations Coordinator'],
#        ['PhD', 'Senior Business Analyst']], dtype=object)

# %%
y = data.iloc[:,5].values
y
# Out:
# array([ 90000.,  65000., 150000.,  60000., 200000.,  55000., 120000.,
#         80000.,  45000., 110000.,  75000., 140000.,  65000., 130000.,
#         40000., 125000.,  90000., 115000.,  35000., 180000.,  80000.,
#        190000.,  50000.,  60000., 140000.,  45000., 110000.,  40000.,
#        140000.,  90000., 250000.,  55000.,  75000.,  65000., 170000.,
#         45000.,  60000., 115000.,  40000., 160000.,  80000., 190000.,
#         60000.,  45000., 130000.,  40000.,  75000., 180000., 120000.,
#         35000., 130000.,  85000.,  60000., 200000.,  50000.,  95000.,
#         65000., 140000.,  55000., 105000., 170000.,  50000.,  80000.,
#        180000.,  35000.,  90000., 120000.,  45000.,  90000., 150000.,
#         65000.,  70000., 190000.,  40000., 120000.,  95000., 160000.,
#        100000., 180000.,  55000.,  70000.,  80000.,  30000., 250000.,
#         40000.,  95000.,  45000.,  80000., 135000.,  55000., 120000.,
#         40000., 105000., 170000.,  75000.,  65000., 160000.,  35000.,
#         90000., 110000.,  45000.,  95000., 150000.,  50000.,  80000.,
#        220000.,  50000.,  60000., 100000.,  40000., 110000.,  95000.,
#        130000.,  90000.,  35000.,  95000.,  65000., 170000.,  45000.,
#        120000., 100000., 180000.,  50000.,  80000., 140000.,  40000.,
#         95000., 110000.,  50000., 105000., 160000.,  45000., 100000.,
#        160000.,  35000.,  55000., 140000.,  50000.,  60000., 120000.,
#         40000., 110000.,  50000., 135000.,  40000.,  90000., 150000.,
#         60000.,  80000., 175000.,  45000., 120000., 140000.,  35000.,
#         95000., 110000.,  50000., 115000., 185000.,  40000.,  90000.,
#        175000.,  45000.,  80000., 120000.,  35000., 110000., 150000.,
#         50000., 105000., 180000.,  40000.,     nan, 140000.,  45000.,
#         85000., 140000.,  50000.,  80000., 170000.,  40000., 105000.,
#        145000.,  40000.,  85000., 130000.,  95000., 100000., 180000.,
#         35000.,  95000., 170000.,  45000.,  95000., 120000.,  40000.,
#         90000., 155000.,  55000., 110000., 180000.,  45000., 130000.,
#         45000.,  90000., 160000.,  50000., 120000., 170000.,  40000.,
#        110000., 150000.,  40000.,  85000., 130000., 100000.,  95000.,
#        180000.,  35000., 100000., 170000.,  45000., 100000., 140000.,
#         40000., 105000., 160000.,  70000., 120000., 190000.,  45000.,
#        120000.,  50000.,  85000., 140000.,  45000., 100000., 140000.,
#         70000., 120000., 160000.,  40000., 120000., 150000.,  70000.,
#         95000., 180000.,  50000.,  95000., 170000.,  40000., 110000.,
#        150000.,  40000.,  85000., 130000., 100000.,  95000., 180000.,
#           350.,     nan, 120000., 160000.,  50000., 110000.,  40000.,
#         95000., 140000.,  60000., 110000., 150000.,  60000.,  90000.,
#        180000.,  40000., 120000., 160000.,  70000.,  95000., 180000.,
#         50000.,  95000., 170000.,  35000., 100000., 150000.,  60000.,
#         85000., 130000.,  65000., 110000., 180000.,  40000.,  90000.,
#        140000.,  60000., 130000., 160000.,  40000., 100000., 180000.,
#         55000., 120000., 150000.,  70000.,  95000., 180000.,  50000.,
#        120000., 170000.,  35000., 100000., 150000.,  60000.,  85000.,
#        130000.,  80000.,  95000.,  40000., 120000., 160000.,  65000.,
#        130000., 180000.,  40000., 100000., 150000.,  55000., 110000.,
#        180000.,  50000., 130000., 160000.,  60000.,  95000., 170000.,
#         40000.,  90000., 150000.,  70000.,  90000., 170000.,  50000.,
#        150000., 160000.,  60000.,  85000., 180000.,  35000., 110000.,
#        160000.,  55000., 110000., 180000.,  50000., 130000., 160000.,
#         60000.,  95000., 170000.,  40000.,  90000., 150000.,  70000.,
#         90000., 170000.,  50000., 150000., 160000.,  60000.,  85000.,
#        170000.,  40000.,  90000., 150000.])

# %%
y = data['Salary'].values
y
# Out:
# array([ 90000.,  65000., 150000.,  60000., 200000.,  55000., 120000.,
#         80000.,  45000., 110000.,  75000., 140000.,  65000., 130000.,
#         40000., 125000.,  90000., 115000.,  35000., 180000.,  80000.,
#        190000.,  50000.,  60000., 140000.,  45000., 110000.,  40000.,
#        140000.,  90000., 250000.,  55000.,  75000.,  65000., 170000.,
#         45000.,  60000., 115000.,  40000., 160000.,  80000., 190000.,
#         60000.,  45000., 130000.,  40000.,  75000., 180000., 120000.,
#         35000., 130000.,  85000.,  60000., 200000.,  50000.,  95000.,
#         65000., 140000.,  55000., 105000., 170000.,  50000.,  80000.,
#        180000.,  35000.,  90000., 120000.,  45000.,  90000., 150000.,
#         65000.,  70000., 190000.,  40000., 120000.,  95000., 160000.,
#        100000., 180000.,  55000.,  70000.,  80000.,  30000., 250000.,
#         40000.,  95000.,  45000.,  80000., 135000.,  55000., 120000.,
#         40000., 105000., 170000.,  75000.,  65000., 160000.,  35000.,
#         90000., 110000.,  45000.,  95000., 150000.,  50000.,  80000.,
#        220000.,  50000.,  60000., 100000.,  40000., 110000.,  95000.,
#        130000.,  90000.,  35000.,  95000.,  65000., 170000.,  45000.,
#        120000., 100000., 180000.,  50000.,  80000., 140000.,  40000.,
#         95000., 110000.,  50000., 105000., 160000.,  45000., 100000.,
#        160000.,  35000.,  55000., 140000.,  50000.,  60000., 120000.,
#         40000., 110000.,  50000., 135000.,  40000.,  90000., 150000.,
#         60000.,  80000., 175000.,  45000., 120000., 140000.,  35000.,
#         95000., 110000.,  50000., 115000., 185000.,  40000.,  90000.,
#        175000.,  45000.,  80000., 120000.,  35000., 110000., 150000.,
#         50000., 105000., 180000.,  40000.,     nan, 140000.,  45000.,
#         85000., 140000.,  50000.,  80000., 170000.,  40000., 105000.,
#        145000.,  40000.,  85000., 130000.,  95000., 100000., 180000.,
#         35000.,  95000., 170000.,  45000.,  95000., 120000.,  40000.,
#         90000., 155000.,  55000., 110000., 180000.,  45000., 130000.,
#         45000.,  90000., 160000.,  50000., 120000., 170000.,  40000.,
#        110000., 150000.,  40000.,  85000., 130000., 100000.,  95000.,
#        180000.,  35000., 100000., 170000.,  45000., 100000., 140000.,
#         40000., 105000., 160000.,  70000., 120000., 190000.,  45000.,
#        120000.,  50000.,  85000., 140000.,  45000., 100000., 140000.,
#         70000., 120000., 160000.,  40000., 120000., 150000.,  70000.,
#         95000., 180000.,  50000.,  95000., 170000.,  40000., 110000.,
#        150000.,  40000.,  85000., 130000., 100000.,  95000., 180000.,
#           350.,     nan, 120000., 160000.,  50000., 110000.,  40000.,
#         95000., 140000.,  60000., 110000., 150000.,  60000.,  90000.,
#        180000.,  40000., 120000., 160000.,  70000.,  95000., 180000.,
#         50000.,  95000., 170000.,  35000., 100000., 150000.,  60000.,
#         85000., 130000.,  65000., 110000., 180000.,  40000.,  90000.,
#        140000.,  60000., 130000., 160000.,  40000., 100000., 180000.,
#         55000., 120000., 150000.,  70000.,  95000., 180000.,  50000.,
#        120000., 170000.,  35000., 100000., 150000.,  60000.,  85000.,
#        130000.,  80000.,  95000.,  40000., 120000., 160000.,  65000.,
#        130000., 180000.,  40000., 100000., 150000.,  55000., 110000.,
#        180000.,  50000., 130000., 160000.,  60000.,  95000., 170000.,
#         40000.,  90000., 150000.,  70000.,  90000., 170000.,  50000.,
#        150000., 160000.,  60000.,  85000., 180000.,  35000., 110000.,
#        160000.,  55000., 110000., 180000.,  50000., 130000., 160000.,
#         60000.,  95000., 170000.,  40000.,  90000., 150000.,  70000.,
#         90000., 170000.,  50000., 150000., 160000.,  60000.,  85000.,
#        170000.,  40000.,  90000., 150000.])

# %% [markdown]
# ##### Split the dataset into training and testing sets

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size = 0.2, random_state = 101)
x_test
# Out:
# array([["Master's", 'Senior Software Engineer'],
#        ["Bachelor's", 'Customer Success Rep'],
#        ["Bachelor's", 'Marketing Coordinator'],
#        ["Bachelor's", 'Junior HR Coordinator'],
#        ['PhD', 'Senior Marketing Manager'],
#        ["Bachelor's", 'Customer Success Manager'],
#        ["Bachelor's", 'Junior Marketing Coordinator'],
#        ["Bachelor's", 'Junior HR Generalist'],
#        ['PhD', 'Principal Engineer'],
#        ["Master's", 'Data Analyst'],
#        ["Master's", 'Director of Operations'],
#        ["Master's", 'Senior Project Coordinator'],
#        ['PhD', 'Senior Data Engineer'],
#        ["Bachelor's", 'Junior Business Development Associate'],
#        ["Bachelor's", 'Senior Financial Analyst'],
#        ['PhD', 'Senior Data Scientist'],
#        ["Bachelor's", 'Sales Associate'],
#        ["Master's", 'UX Researcher'],
#        ["Bachelor's", 'Marketing Coordinator'],
#        ["Bachelor's", 'Junior Account Manager'],
#        [nan, nan],
#        ['PhD', 'Director of Engineering'],
#        ["Bachelor's", 'Junior Business Development Associate'],
#        ["Bachelor's", 'Junior Business Operations Analyst'],
#        ["Master's", 'Senior Financial Analyst'],
#        ["Master's", 'Senior Marketing Manager'],
#        ["Bachelor's", 'Junior Advertising Coordinator'],
#        ["Bachelor's", 'Junior Operations Analyst'],
#        ["Bachelor's", 'Junior Operations Coordinator'],
#        ["Master's", 'Digital Marketing Manager'],
#        ["Bachelor's", 'Senior Accountant'],
#        ["Master's", 'Director of Marketing'],
#        ["Bachelor's", 'Junior Marketing Manager'],
#        ["Bachelor's", 'Senior Operations Manager'],
#        ["Master's", 'Director of Human Capital'],
#        ["Bachelor's", 'Junior Financial Advisor'],
#        ["Bachelor's", 'Senior Project Coordinator'],
#        ["Master's", 'Director of Marketing'],
#        ["Bachelor's", 'Junior Data Analyst'],
#        ["Bachelor's", 'Junior Operations Analyst'],
#        ["Master's", 'Director'],
#        ["Bachelor's", 'Junior Business Development Associate'],
#        ["Bachelor's", 'Senior Human Resources Coordinator'],
#        ["Bachelor's", 'Marketing Coordinator'],
#        ["Bachelor's", 'Senior Project Coordinator'],
#        ["Bachelor's", 'Senior Operations Analyst'],
#        ["Bachelor's", 'Senior Marketing Analyst'],
#        ["Bachelor's", 'Senior Financial Manager'],
#        ["Bachelor's", 'Sales Director'],
#        ["Bachelor's", 'Junior Business Development Associate'],
#        ["Bachelor's", 'Junior Business Analyst'],
#        ["Master's", 'Senior HR Specialist'],
#        ["Bachelor's", 'Senior Business Analyst'],
#        ["Master's", 'Director of Finance'],
#        ["Master's", 'Senior Business Analyst'],
#        ['PhD', 'Senior Data Engineer'],
#        ['PhD', 'Senior Scientist'],
#        ["Bachelor's", 'Senior Marketing Specialist'],
#        ["Bachelor's", 'Data Entry Clerk'],
#        ["Bachelor's", 'Junior Project Manager'],
#        ["Bachelor's", 'Operations Manager'],
#        ["Master's", 'Senior Marketing Analyst'],
#        ["Master's", 'Project Manager'],
#        ["Bachelor's", 'Senior Software Engineer'],
#        ["Bachelor's", 'Senior Marketing Coordinator'],
#        ["Bachelor's", 'Event Coordinator'],
#        ['PhD', 'Senior Engineer'],
#        ['PhD', 'Research Director'],
#        ['PhD', 'Senior Marketing Director'],
#        ['PhD', 'Director of Human Resources'],
#        ["Bachelor's", 'Senior Marketing Specialist'],
#        ["Bachelor's", 'Junior Business Analyst'],
#        ["Bachelor's", 'Senior Sales Representative'],
#        ["Master's", 'Director of Operations'],
#        ['PhD', 'Senior HR Manager']], dtype=object)
